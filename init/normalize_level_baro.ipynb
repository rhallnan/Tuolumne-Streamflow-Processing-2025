# %% [markdown]
# # Normalize Raw Levelogger and Barologger Data
#
# This notebook ingests raw levelogger and barologger data from each year, outputing new level/baro files with consistent naming conventions, headers, and units. Additionally, if the input data is from a levelogger, a log file will be created and populated with the metadata extracted from the raw input file. **This should be run once at the beginning of the project**
#
# Essentially, this notebook adjusts the raw data to conform to conventions specified in config.py.
#
# **Note:**
# * All processing templates expect data to be formatted according to the conventions implemented by this notebook
# * This notebook assumes each year of raw data has its own directory
#
#
# Author of Template and Underlying Code: Joe Ammatelli | (jamma@uw.edu) | July 2022

# %% [markdown]
# ## Import Relevant Libraries
# **Analyst TODO**: Nothing

# %%
import pandas as pd
import os
import sys
import shutil
from datetime import datetime

sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))

import config
import level_baro_utils
import log_utils

sys.path.remove(os.path.abspath(os.path.join('..', 'src')))

# %% [markdown]
# ## Specify path to each year of data
# **Analyst TODO**: Create a string mapping between each year ('YYYY') and the corresponding path to its raw data ('path')

# %%
# TODO: populate dictionary with mappings between year of data and path to raw data
# Example for MAC
# raw_data_dir_by_year = {'2019':'~/tum_raw/raw_19',
#                         '2020':'~/tum_raw/raw_20',
#                         '2021':'~/tum_raw/raw_21'}

# Example for PC
#raw_data_dir_by_year = {'2024':r'C:\Users\RHallnan\OneDrive - DOI\TM Hydro Shared\Lundquist Streamflow\tum_qc_24-25\tum_hydro_qc\unvented_2024\data\raw\tum_raw_24',
#                        '2025':r'C:\Users\RHallnan\OneDrive - DOI\TM Hydro Shared\Lundquist Streamflow\tum_qc_24-25\tum_hydro_qc\unvented_2025\data\raw\tum_raw_25'}


#raw_data_dir_by_year = {'year' : 'path'}

raw_data_dir_by_year = {'2024':r'C:\Users\RHallnan\OneDrive - DOI\TM Hydro Shared\Lundquist Streamflow\tum_qc_24-25\tum_hydro_qc\unvented_2024\data\raw\tum_raw_24',
                        '2025':r'C:\Users\RHallnan\OneDrive - DOI\TM Hydro Shared\Lundquist Streamflow\tum_qc_24-25\tum_hydro_qc\unvented_2025\data\raw\tum_raw_25'}

# %% [markdown]
# ## Normalize Each Year of Data
#
# **Analyst TODO**: Nothing

# %%
for year in raw_data_dir_by_year:
    print('*******************************')
    print(f'Normalizing Data for Year: {year}')
    print('*******************************\n')
    
    # read data from correct year
    data_dir = raw_data_dir_by_year[year]
    
    # write output to correct place
    loc_year_dir_path = os.path.join('..', f'unvented_{year}')
    
    # create directory to store raw data
    raw_dir = os.path.join(loc_year_dir_path, 'data', 'raw')
    if not os.path.exists(raw_dir):
        os.mkdir(raw_dir)
    
    # create dir to store normalized data
    norm_dir = os.path.join(loc_year_dir_path, 'data', 'normalized_raw')
    if not os.path.exists(norm_dir):
        os.mkdir(norm_dir)
    
    # normalize each file in directory
    for fn in os.listdir(data_dir):
        if fn[0] == '.':
            continue
            
        print(f'Normalizing {fn}')
        
        f_path = os.path.join(data_dir, fn)
        
        # infer site
        sitekey = level_baro_utils.infer_site_from_name(fn)
        sitename = None
        if sitekey is None:
            sitename = fn.split('_')[0]
        else:
            sitename = config.SITE_SHORTNAME[sitekey]
        
        # infer sensor type
        sensor_type = level_baro_utils.infer_sensor_type_from_name(fn)
        
        # find header start and read file metadata
        meta, header_num = level_baro_utils.read_meta(f_path)
        
        # read data, convert to desired units, normalize header name
        df = level_baro_utils.read_normalize_solinst_data(f_path, header_num, sensor_type)
    
        # save raw data to
        raw_path = os.path.join(raw_dir, fn)
        shutil.copyfile(f_path, raw_path)
        
        # save normalized file according to naming_convention
        data_name = config.NORMALIZED_FN.format(sensor_type=sensor_type, 
                                                sitename=sitename, 
                                                year=year)
        data_path = os.path.join(norm_dir, data_name)
        df.to_csv(data_path)
        
        # create log file for site and append meta data
        if sensor_type == 'lvl':
            log_dir = os.path.join(loc_year_dir_path, 'logs')
            log_name = f'{sitename}_{year}_log.txt'
            log_path = os.path.join(log_dir, log_name)
            log_utils.create_site_log(log_path, sitename, year)
            log_utils.append_to_log(log_path, 'RAW SOLINST META DATA\n', ''.join(meta))
        
        print(f'Finished Normalizing {fn}\n')
# Out:
# *******************************
# Normalizing Data for Year: 2024
# *******************************
#
# Normalizing BugLab_20240819_Barologger.csv
# Unable to infer site from given fn
# Finished Normalizing BugLab_20240819_Barologger.csv
#
# Normalizing BugLab_20240909_Barologger.csv
# Unable to infer site from given fn
# Finished Normalizing BugLab_20240909_Barologger.csv
#
# Normalizing BugLab_20241106_Barologger.csv
# Unable to infer site from given fn
# Finished Normalizing BugLab_20241106_Barologger.csv
#
# Normalizing DanaFrkBugCamp_20240822_Levelogger.csv
# Finished Normalizing DanaFrkBugCamp_20240822_Levelogger.csv
#
# Normalizing DanaFrkBugCamp_20241029_downloaded.csv
# Finished Normalizing DanaFrkBugCamp_20241029_downloaded.csv
#
# Normalizing DelaneyCrkAbvPCT_20240822_Levelogger.csv
# Finished Normalizing DelaneyCrkAbvPCT_20240822_Levelogger.csv
#
# Normalizing DelaneyCrkAbvPCT_20241030_Levelogger.csv
# Finished Normalizing DelaneyCrkAbvPCT_20241030_Levelogger.csv
#
# Normalizing LyellAbvTwinBridges_20240821_Levelogger.csv
# Finished Normalizing LyellAbvTwinBridges_20240821_Levelogger.csv
#
# Normalizing LyellAbvTwinBridges_20241029_Levelogger.csv
# Finished Normalizing LyellAbvTwinBridges_20241029_Levelogger.csv
#
# Normalizing LyellBlwMaclure_20240828_Barologger_Trimmed.csv
# Finished Normalizing LyellBlwMaclure_20240828_Barologger_Trimmed.csv
#
# Normalizing LyellBlwMaclure_20240828_Levellogger.csv
# Finished Normalizing LyellBlwMaclure_20240828_Levellogger.csv
#
# Normalizing LyellBlwMaclure_20250904_Barologger_trimmed_1.csv
# Finished Normalizing LyellBlwMaclure_20250904_Barologger_trimmed_1.csv
#
# Normalizing LyellBlwMaclure_20250904_Levelogger.csv
# Finished Normalizing LyellBlwMaclure_20250904_Levelogger.csv
#
# Normalizing Tuolumne120_20241106_Levelogger.csv
# Finished Normalizing Tuolumne120_20241106_Levelogger.csv
#
# Normalizing TuolumneMeadowDryWell_Barologger_20240909.csv
# Finished Normalizing TuolumneMeadowDryWell_Barologger_20240909.csv
#
# *******************************
# Normalizing Data for Year: 2025
# *******************************
#
# Normalizing BugLab_20250924_Barologger.csv
# Unable to infer site from given fn
# Finished Normalizing BugLab_20250924_Barologger.csv
#
# Normalizing DanaForkBugCamp_20250819_Levelogger.csv
# Finished Normalizing DanaForkBugCamp_20250819_Levelogger.csv
#
# Normalizing LyellAbvTwinBridges_20250819_Levelogger..csv
# Finished Normalizing LyellAbvTwinBridges_20250819_Levelogger..csv
#
# Normalizing LyellBlwMaclure_20250904_Barologger_trimmed_1.csv
# Finished Normalizing LyellBlwMaclure_20250904_Barologger_trimmed_1.csv
#
# Normalizing LyellBlwMaclure_20250904_Levelogger.csv
# Finished Normalizing LyellBlwMaclure_20250904_Levelogger.csv
